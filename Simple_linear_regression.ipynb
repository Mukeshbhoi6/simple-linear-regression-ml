# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("Salary_dataset.csv")
dataset.head(3)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="YearsExperience",y="Salary",data=dataset)
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x = dataset[['YearsExperience']]
y = dataset[['Salary']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,test_size=0.2,random_state = 11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(x,test_size=0.2,random_state = 11)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
l1 = LinearRegression()
l1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
l1.predict([[1.6]])
# Out:
# C:\Users\Deepak\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[39633.77899292]])

# %%
y_prd = l1.predict(x)

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="YearsExperience",y="Salary",data=dataset)
plt.plot(dataset['YearsExperience'],y_prd,c='red')
plt.show()
